# %%
ascii("a")
ord("a")
print(chr())
# Out:
# c

# %% [markdown]
# #

# %%
a = input()

isinstance(a,int)
# Out:
#  33
# False

# %%
import pandas as pd 
df = pd.DataFrame({
    'CustomerID': [101,102,103,101,104,105,102,106,107,107],
    'Name': ['Amit','Priya','Rahul','Amit','Sneha','Vikram','Priya','Neha','Karan','Karan'],
    'City': ['Pune','Mumbai','Delhi','Pune','Hyderabad','Chennai','Mumbai','Delhi','Pune','Pune'],
    'Amount': [500,700,800,500,900,1000,700,800,1200,1200]
})

print(df)
# Out:
#    CustomerID    Name       City  Amount
# 0         101    Amit       Pune     500
# 1         102   Priya     Mumbai     700
# 2         103   Rahul      Delhi     800
# 3         101    Amit       Pune     500
# 4         104   Sneha  Hyderabad     900
# 5         105  Vikram    Chennai    1000
# 6         102   Priya     Mumbai     700
# 7         106    Neha      Delhi     800
# 8         107   Karan       Pune    1200
# 9         107   Karan       Pune    1200

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# dtype: bool
