# %% [markdown]
# # Pandas methods

# %% [markdown]
# ## 1) import pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2) read / load data frame

# %%
# pd.read_csv()
# pd.read_excel()
# pd.read_json()
# pd.read_sql()
df = pd.read_csv("C:\\Users\\deore\\Downloads\\Task_dataset - Task_dataset.csv")

# %% [markdown]
# ## 5) View data

# %%
# first 5 rows

df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
## last 5 rows 

df.tail()
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn

# %%
# random rows
df.sample(5)
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 167       10168  25.0      127691.0     23673          733  173618.43       0
# 627       10628  24.0      166441.0      5243          815   58850.36       1
# 833       10834  67.0      131931.0     45865          631   51467.32       1
# 694       10695  51.0       45459.0      7133          536  106332.21       3
# 926       10927  22.0       24929.0     32236          741    8503.39       1
#
#     Geography  Gender    Segment Target
# 167       NaN   Other  Corporate  Churn
# 627   Germany  Female        SME  Churn
# 833        UK    Male  Corporate  Churn
# 694       USA   Other        SME   Stay
# 926     India   Other        SME  Churn

# %%
# give number of  (rows,columns)
df.shape
# Out:
# (1020, 11)

# %%
# all columns name
df.columns
# Out:
# Index(['CustomerID', 'Age', 'AnnualIncome', 'Spending', 'CreditScore',
#        'Balance', 'Tenure', 'Geography', 'Gender', 'Segment', 'Target'],
#       dtype='object')

# %%
# total elements
df.size
# Out:
# 11220

# %%
# row labels
df.index
# Out:
# RangeIndex(start=0, stop=1020, step=1)

# %%
# data types
df.dtypes
# Out:
# CustomerID        int64
# Age             float64
# AnnualIncome    float64
# Spending          int64
# CreditScore       int64
# Balance         float64
# Tenure            int64
# Geography        object
# Gender           object
# Segment          object
# Target           object
# dtype: object

# %%
# summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
# statistics
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %% [markdown]
# # 6) Select data

# %%
df1 = pd.read_csv("C:\\Users\\deore\\Downloads\\Task_dataset - Task_dataset.csv")
df['Age']
# Out:
# 0       58.0
# 1       65.0
# 2       56.0
# 3       55.0
# 4       66.0
#         ...
# 1015    43.0
# 1016    25.0
# 1017    49.0
# 1018    38.0
# 1019    62.0
# Name: Age, Length: 1020, dtype: float64

# %%
# single column
df[['Age']] # if you want the column name to be clearly visible as a dataframe
# Out:
#        Age
# 0     58.0
# 1     65.0
# 2     56.0
# 3     55.0
# 4     66.0
# ...    ...
# 1015  43.0
# 1016  25.0
# 1017  49.0
# 1018  38.0
# 1019  62.0
#
# [1020 rows x 1 columns]

# %%
# multiple column
df[['CustomerID','Age']]
# Out:
#       CustomerID   Age
# 0          10001  58.0
# 1          10002  65.0
# 2          10003  56.0
# 3          10004  55.0
# 4          10005  66.0
# ...          ...   ...
# 1015       10450  43.0
# 1016       10753  25.0
# 1017       10810  49.0
# 1018       10267  38.0
# 1019       10059  62.0
#
# [1020 rows x 2 columns]

# %%
# row selection
df.loc[0]
# Out:
# CustomerID        10001
# Age                58.0
# AnnualIncome    49184.0
# Spending           2139
# CreditScore         581
# Balance             NaN
# Tenure                2
# Geography        France
# Gender             Male
# Segment             SME
# Target             Stay
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# CustomerID        10001
# Age                58.0
# AnnualIncome    49184.0
# Spending           2139
# CreditScore         581
# Balance             NaN
# Tenure                2
# Geography        France
# Gender             Male
# Segment             SME
# Target             Stay
# Name: 0, dtype: object

# %%
df.iloc[1:5]
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
df.loc[1:5]
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
# 5       10006  69.0       31390.0     48323          770  107245.62       6
#
#   Geography Gender    Segment Target
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn
# 5     India  Other  Corporate   Stay

# %%
# conditions 
sf =df[df['Age'] > 60]
sf.head(14)
sf[['CustomerID','Age']]
# Out:
#       CustomerID   Age
# 1          10002  65.0
# 4          10005  66.0
# 5          10006  69.0
# 7          10008  67.0
# 11         10012  69.0
# ...          ...   ...
# 1008       10417  70.0
# 1010       10515  62.0
# 1012       10882  61.0
# 1013       10531  64.0
# 1019       10059  62.0
#
# [203 rows x 2 columns]

# %% [markdown]
# # 7) Add/modify columns

# %%
df3 = pd.read_csv("C:\\Users\\deore\\Downloads\\Task_dataset - Task_dataset.csv")
df3.loc[0,'CustomerID'] = 12345

# %%
df3[['CustomerID']]
# Out:
#       CustomerID
# 0          12345
# 1          10002
# 2          10003
# 3          10004
# 4          10005
# ...          ...
# 1015       10450
# 1016       10753
# 1017       10810
# 1018       10267
# 1019       10059
#
# [1020 rows x 1 columns]

# %%
df['Age2'] = df['Age'] * 2 # make a new column Age2

# %%
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target   Age2
# 0          2    France    Male        SME   Stay  116.0
# ...

# %%
df = df.assign(Bonus=df['Balance']*0.1)
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target   Age2      Bonus
# ...

# %% [markdown]
# # 8. Rename columns

# %%
df8 =  pd.read_csv("C:\\Users\\deore\\Downloads\\Task_dataset - Task_dataset.csv")

# %%
df.rename(columns = {'Age':'AAge','CustomerID':'ID'},inplace = True)

# %%
df = df8.add_prefix('add_')
df.add_suffix('_add')
# Out:
#       add_CustomerID_add  add_Age_add  add_AnnualIncome_add  add_Spending_add  \
# 0                  10001         58.0               49184.0              2139
# 1                  10002         65.0              162964.0              6197
# 2                  10003         56.0               26956.0             37281
# 3                  10004         55.0               92926.0               925
# 4                  10005         66.0              108236.0              7198
# ...                  ...          ...                   ...               ...
# 1015               10450         43.0              173620.0              7121
# 1016               10753         25.0               54490.0             13794
# 1017               10810         49.0               82062.0             47170
# 1018               10267         38.0                   NaN             10424
# 1019               10059         62.0               97504.0             36833
#
# ...

# %% [markdown]
# # 9) Delete data
