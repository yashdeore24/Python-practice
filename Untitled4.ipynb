# %%
import pandas as pd

dirty_data = {
    ' CustomerID ': [101, 102, 103, 104, 104, 106, 107, 108, 109, 110],
    'Name': [' Yash', 'Aman ', 'Riya', 'Priya', 'Priya', None, 'Karan', 'Neha', 'Vikas', 'Anjali'],
    'Age': ['22', 'twenty five', 28, -3, -3, 35, None, 200, 29, '31 '],
    'Gender': ['Male', 'M', 'female', 'FEMALE', 'FEMALE', 'Male ', 'm', None, 'Female', 'F'],
    'Annual_Income': ['500000', '₹600,000', None, '450000', '450000', '700000', '800000', '10000000', '-50000', '550000'],
    'Balance': [12000, 15000, None, 18000, 18000, -500, 25000, 9999999, 21000, '22,500'],
    'Active': ['Yes', 'Y', 'No', 'N', 'N', 'YES', 'no', '1', '0', None],
    'Listing_Date': ['2024-01-10', '10/02/2024', '2024/03/15', '2024-13-01', '2024-13-01', None, '15-05-2024', '2024-06-31', '2024-07-20', ' 2024-08-05 '],
    'City': ['Pune', 'Mumbai ', ' pune', 'Delhi', 'Delhi', 'Hyderabad', 'Chennai', 'Pune', None, 'Bangalore']
}

df = pd.DataFrame(dirty_data)

# %%
df
# Out:
#     CustomerID     Name          Age  Gender Annual_Income  Balance Active  \
# 0           101    Yash           22    Male        500000    12000    Yes
# 1           102   Aman   twenty five       M      ₹600,000    15000      Y
# 2           103    Riya           28  female          None     None     No
# 3           104   Priya           -3  FEMALE        450000    18000      N
# 4           104   Priya           -3  FEMALE        450000    18000      N
# 5           106    None           35   Male         700000     -500    YES
# 6           107   Karan         None       m        800000    25000     no
# 7           108    Neha          200    None      10000000  9999999      1
# 8           109   Vikas           29  Female        -50000    21000      0
# 9           110  Anjali          31        F        550000   22,500   None
#
#    Listing_Date       City
# 0    2024-01-10       Pune
# 1    10/02/2024    Mumbai
# 2    2024/03/15       pune
# 3    2024-13-01      Delhi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0    CustomerID    10 non-null     int64
#  1   Name           9 non-null      object
#  2   Age            9 non-null      object
#  3   Gender         9 non-null      object
#  4   Annual_Income  9 non-null      object
#  5   Balance        9 non-null      object
#  6   Active         9 non-null      object
#  7   Listing_Date   9 non-null      object
#  8   City           9 non-null      object
# dtypes: int64(1), object(8)
# memory usage: 852.0+ bytes

# %%
# 2. clean column names
df.columns
# Out:
# Index([' CustomerID ', 'Name', 'Age', 'Gender', 'Annual_Income', 'Balance',
#        'Active', 'Listing_Date', 'City'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Gender', 'Annual_Income', 'Balance',
#        'Active', 'Listing_Date', 'City'],
#       dtype='object')

# %% [markdown]
# # 3.Check duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
#    CustomerID   Name Age  Gender Annual_Income Balance Active Listing_Date  \
# 4         104  Priya  -3  FEMALE        450000   18000      N   2024-13-01
#
#     City
# 4  Delhi

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Name, Age, Gender, Annual_Income, Balance, Active, Listing_Date, City]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 4. Check missing values

# %%
df.isnull().sum()
# Out:
# CustomerID       0
# Name             1
# Age              1
# Gender           1
# Annual_Income    1
# Balance          1
# Active           1
# Listing_Date     1
# City             1
# dtype: int64

# %%
df[df.isnull()]
# Out:
#    CustomerID  Name   Age Gender Annual_Income Balance Active Listing_Date  \
# 0         NaN   NaN   NaN    NaN           NaN     NaN    NaN          NaN
# 1         NaN   NaN   NaN    NaN           NaN     NaN    NaN          NaN
# 2         NaN   NaN   NaN    NaN          None    None    NaN          NaN
# 3         NaN   NaN   NaN    NaN           NaN     NaN    NaN          NaN
# 5         NaN  None   NaN    NaN           NaN     NaN    NaN         None
# 6         NaN   NaN  None    NaN           NaN     NaN    NaN          NaN
# 7         NaN   NaN   NaN   None           NaN     NaN    NaN          NaN
# 8         NaN   NaN   NaN    NaN           NaN     NaN    NaN          NaN
# 9         NaN   NaN   NaN    NaN           NaN     NaN   None          NaN
#
#    City
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8  None
# 9   NaN

# %%
df
# Out:
#    CustomerID    Name          Age  Gender Annual_Income  Balance Active  \
# 0         101    Yash           22    Male        500000    12000    Yes
# 1         102   Aman   twenty five       M      ₹600,000    15000      Y
# 2         103    Riya           28  female          None     None     No
# 3         104   Priya           -3  FEMALE        450000    18000      N
# 5         106    None           35   Male         700000     -500    YES
# 6         107   Karan         None       m        800000    25000     no
# 7         108    Neha          200    None      10000000  9999999      1
# 8         109   Vikas           29  Female        -50000    21000      0
# 9         110  Anjali          31        F        550000   22,500   None
#
#    Listing_Date       City
# 0    2024-01-10       Pune
# 1    10/02/2024    Mumbai
# 2    2024/03/15       pune
# 3    2024-13-01      Delhi
# 5          None  Hyderabad
# 6    15-05-2024    Chennai
# 7    2024-06-31       Pune
# ...

# %%
# Write your code here
List = list(map(int,input().strip().split()))

Tuple = []

def Min(*arg):
   Tuple.append(min(arg[0]))

def Max(*arg):
    Tuple.append(max(arg[0]))

def Avg(*arg):
    Tuple.append(sum(arg[0])/len(arg[0]))

Max((List))
Min((List))
Avg((List))

print(tuple(Tuple))
# Out:
#  12 23 22
# (23, 12, 19.0)
