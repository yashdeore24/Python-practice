# %%
import math

print(math.pi)
print(f"{math.pi:.3f}")
# Out:
# 3.141592653589793
# 3.142

# %% [markdown]
# ###

# %%
import math

var = int(input("Enter any number"))

print(int(math.sqrt(var)))
# Out:
# Enter any number 4
# 2

# %%
num = int(input())
power = int(input())
print(math.pow(num,power))
# Out:
#  3
#  3
# 27.0
