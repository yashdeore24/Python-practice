# %%
string = "yashdeore"

print(string.isalpha())
# Out:
# False

# %%
string = ""
print(string.isalnum())
# Out:
# False

# %%
s = "1ash"
print(s.islower())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 s = "1ash"
# ----> 2 print(s.islower(2))
#
# TypeError: str.islower() takes no arguments (1 given)

# %%
lis = [1,2,3,4] 

lis.sort(reverse = True)
lis
# Out:
# [4, 3, 2, 1]

# %%
# Out:
# [8, 8, 8, 8, 1, 2, 3, 4, 10]

# %%
str = "Uash"
S = str.split("a")
S
# Out:
# ['U', 'sh']
