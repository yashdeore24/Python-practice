# %% [markdown]
# # 1) Which function returns object reference count?

# %%
import sys

a = []
print(sys.getrefcount(a))
# Out:
# 2

# %% [markdown]
# # 2. Which module helps control garbage collection?

# %%
import gc



gc.collect()
gc.disable()
gc.enable()

# %%
# %pip install ipympl
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots()

line, = ax.plot([], [])

ax.set_xlim(0, 2 * np.pi)
ax.set_ylim(-1.2, 1.2)

def update(frame):
    line.set_data(x[:frame], y[:frame])
    return line,

ani = FuncAnimation(
    fig,
    update,
    frames=len(x),
    interval=50,
    blit=True
)

plt.show()
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# Prepare data
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Create figure and axes
fig, ax = plt.subplots()

# Create an empty line
line, = ax.plot([], [])

# Set axis limits
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim(-1.2, 1.2)

# Add title and labels
ax.set_title("Sine Wave Animation")
ax.set_xlabel("X")
ax.set_ylabel("sin(X)")


# Function that updates the graph
def update(frame):
    line.set_data(x[:frame], y[:frame])
    return line,


# Create animation
animation = FuncAnimation(
    fig,
    update,
    frames=len(x),
    interval=50,
    blit=True
)

plt.show()
# Out:
# Requirement already satisfied: ipympl in c:\users\deore\anaconda3\lib\site-packages (0.9.7)
# Requirement already satisfied: ipython<10 in c:\users\deore\anaconda3\lib\site-packages (from ipympl) (9.7.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\deore\anaconda3\lib\site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: matplotlib<4,>=3.5.0 in c:\users\deore\anaconda3\lib\site-packages (from ipympl) (3.10.6)
# Requirement already satisfied: numpy in c:\users\deore\anaconda3\lib\site-packages (from ipympl) (2.3.5)
# Requirement already satisfied: pillow in c:\users\deore\anaconda3\lib\site-packages (from ipympl) (12.0.0)
# Requirement already satisfied: traitlets<6 in c:\users\deore\anaconda3\lib\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\deore\anaconda3\lib\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\deore\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\deore\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\deore\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deore\anaconda3\lib\site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in c:\users\deore\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\deore\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\deore\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\deore\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\deore\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\deore\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
