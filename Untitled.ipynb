# %%
"""Take 10 numbers from the user. Print:

Largest
Smallest
Sum
Average"""

var = [10,5,6,3,1,7,8,9,5]

var.sort()
print(var)
print("smallest is :",var[0])
print("Largest is: ", var[-1])

add = var[0] + var[1] + var[2] + var[3] + var[4] + var[5] + var[6] + var[7] + var[8]
print(add)
average = add/9
print(average)
# Out:
# [1, 3, 5, 5, 6, 7, 8, 9, 10]
# smallest is : 1
# Largest is:  10
# 54
# 6.0

# %%
var = [10,5,6,3,1,7,8,9,5]
var.sort()
first,*all,last = var
print(first)
print(*all)
print(last)

"yes" * (True) or "no"
# Out:
# 1
# 3 5 5 6 7 8 9
# 10

# %%
"yes" * (True) or "no"
# Out:
# 'yes'

# %%
numbers = [1, 2, 3, 4, 5]
doubled = list(map(lambda x: x * 2, numbers))
print(doubled)
# Out:
# [2, 4, 6, 8, 10]
